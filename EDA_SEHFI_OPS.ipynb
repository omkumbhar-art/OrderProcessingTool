# %%
# !pip install pandas openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\admin\appdata\roaming\python\python312\site-packages (2.2.3)
# Requirement already satisfied: openpyxl in c:\users\admin\appdata\roaming\python\python312\site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\appdata\roaming\python\python312\site-packages (from pandas) (2024.2)
# Requirement already satisfied: et-xmlfile in c:\users\admin\appdata\roaming\python\python312\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
df = pd.read_excel(r'C:\Users\Admin\Desktop\customer_seffi.xlsx', skiprows=10) ## Read the Excel file starting from row 11 (skip first 10 rows)
df.head(10)
# Out:
#                                  NEW YORK, NY  10036 Unnamed: 1 Unnamed: 2  \
# 0                                  TEL:(212)491-1474        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2  Note-Pleasefollowtheshipdateandityouarenotship...        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4                                SR#+A11:P21AA11:W43   SHEFIPO#        PD#
# 5                                                  1    1916745    100969P
# 6                                                NaN        NaN        NaN
# 7                                                NaN        NaN        NaN
# 8                                                NaN        NaN        NaN
# 9                                                NaN        NaN        NaN
#
#           Unnamed: 3    Unnamed: 4 Unnamed: 5    SEEPZ, Andheri (East),  \
# 0  FAX:(212)491-1474           NaN        NaN  Mumbai - 400 096, India.
# 1                NaN           NaN        NaN                       NaN
# 2                NaN           NaN        NaN                       NaN
# 3                NaN           NaN         85                       NaN
# 4             Shefi#  VendorStyle#        QTY                     IMAGE
# 5          602501AU2    WP2350G-YG          6                       NaN
# 6                NaN           NaN        NaN                       NaN
# 7                NaN           NaN        NaN                       NaN
# 8                NaN           NaN        NaN                       NaN
# 9                NaN           NaN        NaN                       NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 13      Unnamed: 14  \
# 0        NaN        NaN        NaN  ...         NaN              NaN
# 1        NaN        NaN        NaN  ...         NaN              NaN
# 2        NaN        NaN        NaN  ...         NaN              NaN
# 3        NaN        NaN        NaN  ...         NaN              NaN
# 4  MetalType      Color       Size  ...         NaN         Category
# 5        10K          Y       N.A.  ...         NaN                D
# 6        NaN        NaN        NaN  ...         NaN                D
# 7        NaN        NaN        NaN  ...         NaN  MINIMUM WT-0.69
# 8        NaN        NaN        NaN  ...         NaN              NaN
# 9        NaN        NaN        NaN  ...         NaN              NaN
#
#   Unnamed: 15  Unnamed: 16 Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0         NaN          NaN         NaN         NaN         NaN         NaN
# 1         NaN          NaN         NaN         NaN         NaN         NaN
# 2         NaN          NaN         NaN         NaN         NaN         NaN
# 3         NaN          NaN         NaN         NaN         NaN         NaN
# 4         CUT         CODE          MM       SIEVE     POINTER      DIAQTY
# 5       ROUND      RDI2-DP         3.5     15-15.5        0.16           1
# 6       ROUND      RDI2-DP         2.9     12-12.5         0.1           6
# 7         NaN          NaN         NaN         NaN         NaN           7
# 8         NaN          NaN         NaN         NaN         NaN         NaN
# 9         NaN          NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 21 Unnamed: 22
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4        RMWT     SETCODE
# 5        0.16    WRDPRESS
# 6         0.6    WRDPRESS
# 7        0.76         NaN
# 8         NaN         NaN
# 9         NaN         NaN
#
# [10 rows x 23 columns]

# %%
'''selected_columns = ['VendorStyle#','QTY','Color', 'PD#', 'Description','Shefi#','SHEFIPO#','CODE']  # Replace with your actual column names
df_selected = df[selected_columns]
df_cleaned = df_selected.dropna().copy()
df_cleaned.loc[:, 'Description'] = df_cleaned['Description'].str.replace('\n', ' ', regex=True)
df_cleaned.rename(columns={
    'VendorStyle#': 'StyleCode',
    'QTY': 'OrderQty',
    'Color': 'Tone',
    'PD#': 'ItemRefNo',
    'Description': 'CustomerProductionInstruction',
    'Shefi#': 'SKUNo',
    'SHEFIPO#': 'SHEFIPO#',  # remains unchanged
    'CODE': 'DIA GRADE'
}, inplace=True)

# Add SrNo. as the first column (indexing from 1)
df_cleaned.insert(loc=0, column='SrNo.', value=range(1, len(df_cleaned) + 1))

df_cleaned.insert(loc=1, column='ItemSize', value='')  # or use default value like np.nan or a specific size
# Insert 'StockType' and 'MakeType' after 'ItemRefNo'
item_ref_index = df_cleaned.columns.get_loc('ItemRefNo')
df_cleaned.insert(loc=item_ref_index + 1, column='StockType', value='')
df_cleaned.insert(loc=item_ref_index + 2, column='MakeType', value='')

# Insert 9 columns after 'SKUNo'
sku_index = df_cleaned.columns.get_loc('SKUNo')
new_columns = [
    'Basestoneminwt', 'Basestonemaxwt', 'Basemetalminwt', 'Basemetalmaxwt',
    'Productiondeliverydate', 'Expecteddeliverydate', 'null', 'SetPrice', 'StoneQuality'
]

for i, col in enumerate(new_columns):
    df_cleaned.insert(loc=sku_index + 1 + i, column=col, value='')

# Display the first 112 rows
df_cleaned.head(112)'''
# Out:
#     SrNo. ItemSize    StyleCode  OrderQty Tone ItemRefNo StockType MakeType  \
# 0       1            WP2350G-YG       6.0    Y   100969P
# 6       2            WP2350G-WG       2.0    W   100969P
# 12      3            WP2350K-WG       1.0    W   200646P
# 18      4            WP2350A-YG       6.0    Y   110486P
# 24      5            WP2350A-YG       6.0    Y   110486P
# 30      6            WP2350A-WG       5.0    W   110486P
# 36      7            WP2350A-WG       5.0    W   110486P
# 42      8            WP2350C-WG       4.0    W   101289P
# 48      9            WP2350D-YG       4.0    Y   100967P
# 54     10            WP2350D-WG       5.0    W   100967P
# 60     11            WP2350D-WG       5.0    W   100967P
# 65     12            WP2350E-YG       9.0    Y   110489P
# 71     13            WP2350E-WG       9.0    W   110489P
# 77     14            WP2350F-YG       5.0    Y   100968P
# 83     15            WP2350F-WG       9.0    W   100968P
# 89     16            WP2350X-WG       2.0    W   201272E
# 96     17            WP2350G-YG       2.0    Y   101289P
#
#                         CustomerProductionInstruction      SKUNo  ...  \
# 0          10KY PEND: 1.00CT FLOWER W/ BAIL PRONG SET  602501AU2  ...
# 6          10KW PEND: 1.00CT FLOWER W/ BAIL PRONG SET  602501BU2  ...
# 12  10KW PEND: 7 RD. 2.00CTW FLOWER W/ BAIL PRONG SET  602502BU2  ...
# 18  PENDENT: 10KY, TW:0.10CT, FLOWER W/ BAIL PRONG...  602510AU2  ...
# 24  PENDENT: 10KY, TW:0.10CT, FLOWER W/ BAIL PRONG...  602510AU2  ...
# 30  PENDENT: 10KW FLOWER CLUSTER W/ BAIL PRONG SET...  602510BU2  ...
# 36  PENDENT: 10KW FLOWER CLUSTER W/ BAIL PRONG SET...  602510BU2  ...
# 42         10KW PEND: 0.20CT FLOWER W/ BAIL PRONG SET  602520BU2  ...
# 48         10KY PEND: 0.25CT FLOWER W/ BAIL PRONG SET  602525AU2  ...
# 54        10KW PEND: 0.25CTW FLOWER W/ BAIL PRONG SET  602525BU2  ...
# 60        10KW PEND: 0.25CTW FLOWER W/ BAIL PRONG SET  602525BU2  ...
# 65        10KY PEND: 0.33CTW FLOWER W/ BAIL PRONG SET  602533AU2  ...
# 71           10KW PEND: 0.33 FLOWER W/ BAIL PRONG SET  602533BU2  ...
# 77         10KY PEND: 0.50CT FLOWER W/ BAIL PRONG SET  602550AU2  ...
# 83         10KW PEND: 0.50CT FLOWER W/ BAIL PRONG SET  602550BU2  ...
# 89                 PENDANT : 10KW FLOWER 7RD. 0.65CTW  602565BU2  ...
# 96                PENDANT :10KY 7 STONE FLOWER 3/4CTW  602575AU2  ...
#
#    Basestonemaxwt Basemetalminwt Basemetalmaxwt Productiondeliverydate  \
# 0
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54
# 60
# 65
# 71
# 77
# 83
# 89
# 96
#
#    Expecteddeliverydate null SetPrice StoneQuality   SHEFIPO#  DIA GRADE
# 0                                                   1916745.0    RDI2-DP
# 6                                                   1916745.0    RDI2-DP
# 12                                                  1916745.0    RDI2-DP
# 18                                                  1916745.0    RDI2-DP
# 24                                                  1916745.0    RDI2-DP
# 30                                                  1916745.0    RDI2-DP
# 36                                                  1916745.0    RDI2-DP
# 42                                                  1916745.0    RDI2-DP
# 48                                                  1916745.0    RDI2-DP
# 54                                                  1916745.0    RDI2-DP
# 60                                                  1916745.0    RDI2-DP
# 65                                                  1916745.0    RDI2-DP
# 71                                                  1916745.0    RDI2-DP
# 77                                                  1916745.0    RDI2-DP
# 83                                                  1916745.0    RDI2-DP
# 89                                                  1916745.0    RDI2-DP
# 96                                                  1916745.0    RDI2-DP
#
# [17 rows x 21 columns]

# %%
'''# Step 1: Read cell A2 from Excel using openpyxl engine
po_value = pd.read_excel(r'C:\Users\Admin\Desktop\customer_seffi.xlsx', header=None, engine='openpyxl').iloc[1, 0]  # A2 is row 1, col 0 (0-indexed)

# Step 2: Read the actual data starting from row 11 (skip first 10 rows if needed)
df = pd.read_excel(r'C:\Users\Admin\Desktop\customer_seffi.xlsx', skiprows=10)

# Select specific columns
selected_columns = ['VendorStyle#', 'QTY', 'Color', 'PD#', 'Description', 'Shefi#', 'SHEFIPO#', 'CODE']
df_selected = df[selected_columns]

# Drop rows with NaN values and make a copy
df_cleaned = df_selected.dropna().copy()

# Clean newline characters from 'Description'
df_cleaned.loc[:, 'Description'] = df_cleaned['Description'].str.replace('\n', ' ', regex=True)

# Rename columns
df_cleaned.rename(columns={
    'VendorStyle#': 'StyleCode',
    'QTY': 'OrderQty',
    'Color': 'Tone',
    'PD#': 'ItemRefNo',
    'Description': 'CustomerProductionInstruction',
    'Shefi#': 'SKUNo',
    'SHEFIPO#': 'SHEFIPO#',
    'CODE': 'DIA GRADE'
}, inplace=True)

# Add SrNo. as the first column (indexing from 1)
df_cleaned.insert(loc=0, column='SrNo.', value=range(1, len(df_cleaned) + 1))

# Add ItemSize after StyleCode
df_cleaned.insert(loc=2, column='ItemSize', value='')

# Add StockType and MakeType after ItemRefNo
item_ref_index = df_cleaned.columns.get_loc('ItemRefNo')
df_cleaned.insert(loc=item_ref_index + 1, column='StockType', value='')
df_cleaned.insert(loc=item_ref_index + 2, column='MakeType', value='')

# Add 9 columns after SKUNo
sku_index = df_cleaned.columns.get_loc('SKUNo')
new_columns = [
    'Basestoneminwt', 'Basestonemaxwt', 'Basemetalminwt', 'Basemetalmaxwt',
    'Productiondeliverydate', 'Expecteddeliverydate', 'null', 'SetPrice', 'StoneQuality'
]
for i, col in enumerate(new_columns):
    df_cleaned.insert(loc=sku_index + 1 + i, column=col, value='')

# Insert ItemPoNo column with value from A2 (place it at the end or wherever preferred)
df_cleaned['ItemPoNo'] = po_value

# Show the first 112 rows
df_cleaned.head(112)'''
# Out:
#     SrNo.    StyleCode ItemSize  OrderQty Tone ItemRefNo StockType MakeType  \
# 0       1   WP2350G-YG                6.0    Y   100969P
# 6       2   WP2350G-WG                2.0    W   100969P
# 12      3   WP2350K-WG                1.0    W   200646P
# 18      4   WP2350A-YG                6.0    Y   110486P
# 24      5   WP2350A-YG                6.0    Y   110486P
# 30      6   WP2350A-WG                5.0    W   110486P
# 36      7   WP2350A-WG                5.0    W   110486P
# 42      8   WP2350C-WG                4.0    W   101289P
# 48      9   WP2350D-YG                4.0    Y   100967P
# 54     10   WP2350D-WG                5.0    W   100967P
# 60     11   WP2350D-WG                5.0    W   100967P
# 65     12   WP2350E-YG                9.0    Y   110489P
# 71     13   WP2350E-WG                9.0    W   110489P
# 77     14   WP2350F-YG                5.0    Y   100968P
# 83     15   WP2350F-WG                9.0    W   100968P
# 89     16   WP2350X-WG                2.0    W   201272E
# 96     17   WP2350G-YG                2.0    Y   101289P
#
#                         CustomerProductionInstruction      SKUNo  ...  \
# 0          10KY PEND: 1.00CT FLOWER W/ BAIL PRONG SET  602501AU2  ...
# 6          10KW PEND: 1.00CT FLOWER W/ BAIL PRONG SET  602501BU2  ...
# 12  10KW PEND: 7 RD. 2.00CTW FLOWER W/ BAIL PRONG SET  602502BU2  ...
# 18  PENDENT: 10KY, TW:0.10CT, FLOWER W/ BAIL PRONG...  602510AU2  ...
# 24  PENDENT: 10KY, TW:0.10CT, FLOWER W/ BAIL PRONG...  602510AU2  ...
# 30  PENDENT: 10KW FLOWER CLUSTER W/ BAIL PRONG SET...  602510BU2  ...
# 36  PENDENT: 10KW FLOWER CLUSTER W/ BAIL PRONG SET...  602510BU2  ...
# 42         10KW PEND: 0.20CT FLOWER W/ BAIL PRONG SET  602520BU2  ...
# 48         10KY PEND: 0.25CT FLOWER W/ BAIL PRONG SET  602525AU2  ...
# 54        10KW PEND: 0.25CTW FLOWER W/ BAIL PRONG SET  602525BU2  ...
# 60        10KW PEND: 0.25CTW FLOWER W/ BAIL PRONG SET  602525BU2  ...
# 65        10KY PEND: 0.33CTW FLOWER W/ BAIL PRONG SET  602533AU2  ...
# 71           10KW PEND: 0.33 FLOWER W/ BAIL PRONG SET  602533BU2  ...
# 77         10KY PEND: 0.50CT FLOWER W/ BAIL PRONG SET  602550AU2  ...
# 83         10KW PEND: 0.50CT FLOWER W/ BAIL PRONG SET  602550BU2  ...
# 89                 PENDANT : 10KW FLOWER 7RD. 0.65CTW  602565BU2  ...
# 96                PENDANT :10KY 7 STONE FLOWER 3/4CTW  602575AU2  ...
#
#    Basemetalminwt Basemetalmaxwt Productiondeliverydate Expecteddeliverydate  \
# 0
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54
# 60
# 65
# 71
# 77
# 83
# 89
# 96
#
#    null SetPrice StoneQuality   SHEFIPO# DIA GRADE       ItemPoNo
# 0                              1916745.0   RDI2-DP  PO# SJS2_0028
# 6                              1916745.0   RDI2-DP  PO# SJS2_0028
# 12                             1916745.0   RDI2-DP  PO# SJS2_0028
# 18                             1916745.0   RDI2-DP  PO# SJS2_0028
# 24                             1916745.0   RDI2-DP  PO# SJS2_0028
# 30                             1916745.0   RDI2-DP  PO# SJS2_0028
# 36                             1916745.0   RDI2-DP  PO# SJS2_0028
# 42                             1916745.0   RDI2-DP  PO# SJS2_0028
# 48                             1916745.0   RDI2-DP  PO# SJS2_0028
# 54                             1916745.0   RDI2-DP  PO# SJS2_0028
# 60                             1916745.0   RDI2-DP  PO# SJS2_0028
# 65                             1916745.0   RDI2-DP  PO# SJS2_0028
# 71                             1916745.0   RDI2-DP  PO# SJS2_0028
# 77                             1916745.0   RDI2-DP  PO# SJS2_0028
# 83                             1916745.0   RDI2-DP  PO# SJS2_0028
# 89                             1916745.0   RDI2-DP  PO# SJS2_0028
# 96                             1916745.0   RDI2-DP  PO# SJS2_0028
#
# [17 rows x 22 columns]

# %%
'''# Step 1: Read cell A2 from Excel using openpyxl engine
po_value = pd.read_excel(r'C:\Users\Admin\Desktop\customer_seffi.xlsx', header=None, engine='openpyxl').iloc[1, 0]

# Step 2: Read the actual data starting from row 11 (skip first 10 rows)
df = pd.read_excel(r'C:\Users\Admin\Desktop\customer_seffi.xlsx', skiprows=10)

# Select specific columns
selected_columns = ['VendorStyle#', 'QTY','MetalType','Color', 'PD#', 'Description', 'Shefi#', 'SHEFIPO#', 'CODE']
df_selected = df[selected_columns]

# Drop rows with NaN values and make a copy
df_cleaned = df_selected.dropna().copy()

# Clean newline characters from 'Description'
df_cleaned.loc[:, 'Description'] = df_cleaned['Description'].str.replace('\n', ' ', regex=True)

# Rename columns
df_cleaned.rename(columns={
    'VendorStyle#': 'StyleCode',
    'QTY': 'OrderQty',
    'MetalType': 'Metal',
    'Color': 'Tone',
    'PD#': 'ItemRefNo',
    'Description': 'CustomerProductionInstruction',
    'Shefi#': 'SKUNo',
    'SHEFIPO#': 'SHEFIPO#',
    'CODE': 'DIA GRADE'
}, inplace=True)

# Add SrNo. as the first column
df_cleaned.insert(loc=0, column='SrNo.', value=range(1, len(df_cleaned) + 1))

# Add ItemSize after StyleCode
df_cleaned.insert(loc=2, column='ItemSize', value='')

# Insert 'OrderItemPcs' after 'OrderQty' (Metal column removed)
order_qty_index = df_cleaned.columns.get_loc('OrderQty')
df_cleaned.insert(loc=order_qty_index + 1, column='OrderItemPcs', value='')

# Add StockType and MakeType after ItemRefNo
item_ref_index = df_cleaned.columns.get_loc('ItemRefNo')
df_cleaned.insert(loc=item_ref_index + 1, column='StockType', value='')
df_cleaned.insert(loc=item_ref_index + 2, column='MakeType', value='')

# Add 9 columns after SKUNo
sku_index = df_cleaned.columns.get_loc('SKUNo')
new_columns = [
    'Basestoneminwt', 'Basestonemaxwt', 'Basemetalminwt', 'Basemetalmaxwt',
    'Productiondeliverydate', 'Expecteddeliverydate', 'null', 'SetPrice', 'StoneQuality'
]
for i, col in enumerate(new_columns):
    df_cleaned.insert(loc=sku_index + 1 + i, column=col, value='')

# Insert 'ItemPoNo' after 'Tone'
tone_index = df_cleaned.columns.get_loc('Tone')
df_cleaned.insert(loc=tone_index + 1, column='ItemPoNo', value=po_value)

# Show first 112 rows
df_cleaned.head(112)'''
# Out:
#     SrNo.    StyleCode ItemSize  OrderQty OrderItemPcs Metal Tone  \
# 0       1   WP2350G-YG                6.0                10K    Y
# 6       2   WP2350G-WG                2.0                10K    W
# 12      3   WP2350K-WG                1.0                10K    W
# 18      4   WP2350A-YG                6.0                10K    Y
# 24      5   WP2350A-YG                6.0                10K    Y
# 30      6   WP2350A-WG                5.0                10K    W
# 36      7   WP2350A-WG                5.0                10K    W
# 42      8   WP2350C-WG                4.0                10K    W
# 48      9   WP2350D-YG                4.0                10K    Y
# 54     10   WP2350D-WG                5.0                10K    W
# 60     11   WP2350D-WG                5.0                10K    W
# 65     12   WP2350E-YG                9.0                10K    Y
# 71     13   WP2350E-WG                9.0                10K    W
# 77     14   WP2350F-YG                5.0                10K    Y
# 83     15   WP2350F-WG                9.0                10K    W
# 89     16   WP2350X-WG                2.0                10K    W
# 96     17   WP2350G-YG                2.0                10K    Y
#
#          ItemPoNo ItemRefNo StockType  ... Basestonemaxwt Basemetalminwt  \
# 0   PO# SJS2_0028   100969P            ...
# 6   PO# SJS2_0028   100969P            ...
# 12  PO# SJS2_0028   200646P            ...
# 18  PO# SJS2_0028   110486P            ...
# 24  PO# SJS2_0028   110486P            ...
# 30  PO# SJS2_0028   110486P            ...
# 36  PO# SJS2_0028   110486P            ...
# 42  PO# SJS2_0028   101289P            ...
# 48  PO# SJS2_0028   100967P            ...
# 54  PO# SJS2_0028   100967P            ...
# 60  PO# SJS2_0028   100967P            ...
# 65  PO# SJS2_0028   110489P            ...
# 71  PO# SJS2_0028   110489P            ...
# 77  PO# SJS2_0028   100968P            ...
# 83  PO# SJS2_0028   100968P            ...
# 89  PO# SJS2_0028   201272E            ...
# 96  PO# SJS2_0028   101289P            ...
#
#    Basemetalmaxwt Productiondeliverydate Expecteddeliverydate null SetPrice  \
# 0
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54
# 60
# 65
# 71
# 77
# 83
# 89
# 96
#
#    StoneQuality   SHEFIPO# DIA GRADE
# 0                1916745.0   RDI2-DP
# 6                1916745.0   RDI2-DP
# 12               1916745.0   RDI2-DP
# 18               1916745.0   RDI2-DP
# 24               1916745.0   RDI2-DP
# 30               1916745.0   RDI2-DP
# 36               1916745.0   RDI2-DP
# 42               1916745.0   RDI2-DP
# 48               1916745.0   RDI2-DP
# 54               1916745.0   RDI2-DP
# 60               1916745.0   RDI2-DP
# 65               1916745.0   RDI2-DP
# 71               1916745.0   RDI2-DP
# 77               1916745.0   RDI2-DP
# 83               1916745.0   RDI2-DP
# 89               1916745.0   RDI2-DP
# 96               1916745.0   RDI2-DP
#
# [17 rows x 24 columns]

# %%
import re
selected_columns = ['VendorStyle#', 'QTY', 'MetalType', 'Color', 'PD#', 'Description', 'Shefi#', 'SHEFIPO#', 'CODE']
df_selected = df[selected_columns]

# Drop rows with NaN values and make a copy
df_cleaned = df_selected.dropna().copy()

# Clean newline characters from 'Description'
df_cleaned.loc[:, 'Description'] = df_cleaned['Description'].str.replace('\n', ' ', regex=True)

# Rename columns
df_cleaned.rename(columns={
    'VendorStyle#': 'StyleCode',
    'QTY': 'OrderQty',
    'MetalType': 'MetalType',
    'Color': 'Tone',
    'PD#': 'ItemRefNo',
    'Description': 'CustomerProductionInstruction',
    'Shefi#': 'SKUNo',
    'SHEFIPO#': 'SHEFIPO#',
    'CODE': 'DIA GRADE'
}, inplace=True)

# Add SrNo. as the first column
df_cleaned.insert(loc=0, column='SrNo.', value=range(1, len(df_cleaned) + 1))

# Add ItemSize after StyleCode
df_cleaned.insert(loc=2, column='ItemSize', value='')

# Insert 'OrderItemPcs' after 'OrderQty'
order_qty_index = df_cleaned.columns.get_loc('OrderQty')
df_cleaned.insert(loc=order_qty_index + 1, column='OrderItemPcs', value='')

# Add StockType and MakeType after ItemRefNo
item_ref_index = df_cleaned.columns.get_loc('ItemRefNo')
df_cleaned.insert(loc=item_ref_index + 1, column='StockType', value='')
df_cleaned.insert(loc=item_ref_index + 2, column='MakeType', value='')

# Add 9 columns after SKUNo
sku_index = df_cleaned.columns.get_loc('SKUNo')
new_columns = [
    'Basestoneminwt', 'Basestonemaxwt', 'Basemetalminwt', 'Basemetalmaxwt',
    'Productiondeliverydate', 'Expecteddeliverydate', 'null', 'SetPrice', 'StoneQuality'
]
for i, col in enumerate(new_columns):
    df_cleaned.insert(loc=sku_index + 1 + i, column=col, value='')

# Insert 'ItemPoNo' after 'Tone'
tone_index = df_cleaned.columns.get_loc('Tone')
df_cleaned.insert(loc=tone_index + 1, column='ItemPoNo', value=po_value)  # Ensure po_value is defined

# ✅ Create 'Metal' column using: last char of StyleCode + numeric part of MetalType + Tone
df_cleaned['Metal'] = df_cleaned.apply(
    lambda row: str(row['StyleCode'])[-1] + re.sub(r'\D', '', str(row['MetalType'])) + str(row['Tone']),
    axis=1
)

# ✅ Replace 'MetalType' column with 'Metal'
metal_type_index = df_cleaned.columns.get_loc('MetalType')
df_cleaned.drop(columns=['MetalType'], inplace=True)
metal_col = df_cleaned.pop('Metal')
df_cleaned.insert(loc=metal_type_index, column='Metal', value=metal_col)

# ✅ Show first 112 rows
df_cleaned.head(112)
# Out:
#     SrNo.    StyleCode ItemSize  OrderQty OrderItemPcs Metal Tone  \
# 0       1   WP2350G-YG                6.0               G10Y    Y
# 6       2   WP2350G-WG                2.0               G10W    W
# 12      3   WP2350K-WG                1.0               G10W    W
# 18      4   WP2350A-YG                6.0               G10Y    Y
# 24      5   WP2350A-YG                6.0               G10Y    Y
# 30      6   WP2350A-WG                5.0               G10W    W
# 36      7   WP2350A-WG                5.0               G10W    W
# 42      8   WP2350C-WG                4.0               G10W    W
# 48      9   WP2350D-YG                4.0               G10Y    Y
# 54     10   WP2350D-WG                5.0               G10W    W
# 60     11   WP2350D-WG                5.0               G10W    W
# 65     12   WP2350E-YG                9.0               G10Y    Y
# 71     13   WP2350E-WG                9.0               G10W    W
# 77     14   WP2350F-YG                5.0               G10Y    Y
# 83     15   WP2350F-WG                9.0               G10W    W
# 89     16   WP2350X-WG                2.0               G10W    W
# 96     17   WP2350G-YG                2.0               G10Y    Y
#
#          ItemPoNo ItemRefNo StockType  ... Basestonemaxwt Basemetalminwt  \
# 0   PO# SJS2_0028   100969P            ...
# 6   PO# SJS2_0028   100969P            ...
# 12  PO# SJS2_0028   200646P            ...
# 18  PO# SJS2_0028   110486P            ...
# 24  PO# SJS2_0028   110486P            ...
# 30  PO# SJS2_0028   110486P            ...
# 36  PO# SJS2_0028   110486P            ...
# 42  PO# SJS2_0028   101289P            ...
# 48  PO# SJS2_0028   100967P            ...
# 54  PO# SJS2_0028   100967P            ...
# 60  PO# SJS2_0028   100967P            ...
# 65  PO# SJS2_0028   110489P            ...
# 71  PO# SJS2_0028   110489P            ...
# 77  PO# SJS2_0028   100968P            ...
# 83  PO# SJS2_0028   100968P            ...
# 89  PO# SJS2_0028   201272E            ...
# 96  PO# SJS2_0028   101289P            ...
#
#    Basemetalmaxwt Productiondeliverydate Expecteddeliverydate null SetPrice  \
# 0
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54
# 60
# 65
# 71
# 77
# 83
# 89
# 96
#
#    StoneQuality   SHEFIPO# DIA GRADE
# 0                1916745.0   RDI2-DP
# 6                1916745.0   RDI2-DP
# 12               1916745.0   RDI2-DP
# 18               1916745.0   RDI2-DP
# 24               1916745.0   RDI2-DP
# 30               1916745.0   RDI2-DP
# 36               1916745.0   RDI2-DP
# 42               1916745.0   RDI2-DP
# 48               1916745.0   RDI2-DP
# 54               1916745.0   RDI2-DP
# 60               1916745.0   RDI2-DP
# 65               1916745.0   RDI2-DP
# 71               1916745.0   RDI2-DP
# 77               1916745.0   RDI2-DP
# 83               1916745.0   RDI2-DP
# 89               1916745.0   RDI2-DP
# 96               1916745.0   RDI2-DP
#
# [17 rows x 24 columns]

# %%
'''import re

# Select specific columns
selected_columns = ['VendorStyle#', 'QTY', 'MetalType', 'Color', 'PD#', 'Description', 'Shefi#', 'SHEFIPO#', 'CODE']
df_selected = df[selected_columns]

# Drop rows with NaN values and make a copy
df_cleaned = df_selected.dropna().copy()

# Clean newline characters from 'Description'
df_cleaned.loc[:, 'Description'] = df_cleaned['Description'].str.replace('\n', ' ', regex=True)

# Rename columns
df_cleaned.rename(columns={
    'VendorStyle#': 'StyleCode',
    'QTY': 'OrderQty',
    'MetalType': 'MetalType',
    'Color': 'Tone',
    'PD#': 'ItemRefNo',
    'Description': 'CustomerProductionInstruction',
    'Shefi#': 'SKUNo',
    'SHEFIPO#': 'SHEFIPO#',
    'CODE': 'DIA GRADE'
}, inplace=True)

# Add SrNo. as the first column
df_cleaned.insert(loc=0, column='SrNo.', value=range(1, len(df_cleaned) + 1))

# Add ItemSize after StyleCode
df_cleaned.insert(loc=2, column='ItemSize', value='')

# Insert 'OrderItemPcs' after 'OrderQty'
order_qty_index = df_cleaned.columns.get_loc('OrderQty')
df_cleaned.insert(loc=order_qty_index + 1, column='OrderItemPcs', value='')

# Add StockType and MakeType after ItemRefNo
item_ref_index = df_cleaned.columns.get_loc('ItemRefNo')
df_cleaned.insert(loc=item_ref_index + 1, column='StockType', value='')
df_cleaned.insert(loc=item_ref_index + 2, column='MakeType', value='')

# Insert 'OrderGroup' and 'Certificate' left of 'SKUNo'
sku_index = df_cleaned.columns.get_loc('SKUNo')
df_cleaned.insert(loc=sku_index, column='OrderGroup', value='SHEFI')
df_cleaned.insert(loc=sku_index + 1, column='Certificate', value='')

# Add 9 columns after SKUNo (which is now 2 columns to the right)
sku_index = df_cleaned.columns.get_loc('SKUNo')
new_columns = [
    'Basestoneminwt', 'Basestonemaxwt', 'Basemetalminwt', 'Basemetalmaxwt',
    'Productiondeliverydate', 'Expecteddeliverydate', 'null', 'SetPrice', 'StoneQuality'
]
for i, col in enumerate(new_columns):
    df_cleaned.insert(loc=sku_index + 1 + i, column=col, value='')

# Insert 'ItemPoNo' after 'Tone'
tone_index = df_cleaned.columns.get_loc('Tone')
df_cleaned.insert(loc=tone_index + 1, column='ItemPoNo', value=po_value)  # Ensure po_value is defined

# Create 'Metal' column using: last char of StyleCode + numeric part of MetalType + Tone
df_cleaned['Metal'] = df_cleaned.apply(
    lambda row: str(row['StyleCode'])[-1] + re.sub(r'\D', '', str(row['MetalType'])) + str(row['Tone']),
    axis=1
)

# Replace 'MetalType' column with 'Metal'
metal_type_index = df_cleaned.columns.get_loc('MetalType')
df_cleaned.drop(columns=['MetalType'], inplace=True)
metal_col = df_cleaned.pop('Metal')
df_cleaned.insert(loc=metal_type_index, column='Metal', value=metal_col)

# Show first 112 rows
df_cleaned.head(112)'''
# Out:
#     SrNo.    StyleCode ItemSize  OrderQty OrderItemPcs Metal Tone  \
# 0       1   WP2350G-YG                6.0               G10Y    Y
# 6       2   WP2350G-WG                2.0               G10W    W
# 12      3   WP2350K-WG                1.0               G10W    W
# 18      4   WP2350A-YG                6.0               G10Y    Y
# 24      5   WP2350A-YG                6.0               G10Y    Y
# 30      6   WP2350A-WG                5.0               G10W    W
# 36      7   WP2350A-WG                5.0               G10W    W
# 42      8   WP2350C-WG                4.0               G10W    W
# 48      9   WP2350D-YG                4.0               G10Y    Y
# 54     10   WP2350D-WG                5.0               G10W    W
# 60     11   WP2350D-WG                5.0               G10W    W
# 65     12   WP2350E-YG                9.0               G10Y    Y
# 71     13   WP2350E-WG                9.0               G10W    W
# 77     14   WP2350F-YG                5.0               G10Y    Y
# 83     15   WP2350F-WG                9.0               G10W    W
# 89     16   WP2350X-WG                2.0               G10W    W
# 96     17   WP2350G-YG                2.0               G10Y    Y
#
#          ItemPoNo ItemRefNo StockType  ... Basestonemaxwt Basemetalminwt  \
# 0   PO# SJS2_0028   100969P            ...
# 6   PO# SJS2_0028   100969P            ...
# 12  PO# SJS2_0028   200646P            ...
# 18  PO# SJS2_0028   110486P            ...
# 24  PO# SJS2_0028   110486P            ...
# 30  PO# SJS2_0028   110486P            ...
# 36  PO# SJS2_0028   110486P            ...
# 42  PO# SJS2_0028   101289P            ...
# 48  PO# SJS2_0028   100967P            ...
# 54  PO# SJS2_0028   100967P            ...
# 60  PO# SJS2_0028   100967P            ...
# 65  PO# SJS2_0028   110489P            ...
# 71  PO# SJS2_0028   110489P            ...
# 77  PO# SJS2_0028   100968P            ...
# 83  PO# SJS2_0028   100968P            ...
# 89  PO# SJS2_0028   201272E            ...
# 96  PO# SJS2_0028   101289P            ...
#
#    Basemetalmaxwt Productiondeliverydate Expecteddeliverydate null SetPrice  \
# 0
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54
# 60
# 65
# 71
# 77
# 83
# 89
# 96
#
#    StoneQuality   SHEFIPO# DIA GRADE
# 0                1916745.0   RDI2-DP
# 6                1916745.0   RDI2-DP
# 12               1916745.0   RDI2-DP
# 18               1916745.0   RDI2-DP
# 24               1916745.0   RDI2-DP
# 30               1916745.0   RDI2-DP
# 36               1916745.0   RDI2-DP
# 42               1916745.0   RDI2-DP
# 48               1916745.0   RDI2-DP
# 54               1916745.0   RDI2-DP
# 60               1916745.0   RDI2-DP
# 65               1916745.0   RDI2-DP
# 71               1916745.0   RDI2-DP
# 77               1916745.0   RDI2-DP
# 83               1916745.0   RDI2-DP
# 89               1916745.0   RDI2-DP
# 96               1916745.0   RDI2-DP
#
# [17 rows x 26 columns]

# %%
import re
selected_columns = ['VendorStyle#', 'QTY', 'MetalType', 'Color', 'PD#', 'Description', 'Shefi#', 'SHEFIPO#', 'CODE']
df_selected = df[selected_columns]

# Drop rows with NaN values and make a copy
df_cleaned = df_selected.dropna().copy()

# Clean newline characters from 'Description'
df_cleaned.loc[:, 'Description'] = df_cleaned['Description'].str.replace('\n', ' ', regex=True)

# Rename columns
df_cleaned.rename(columns={
    'VendorStyle#': 'StyleCode',
    'QTY': 'OrderQty',
    'MetalType': 'MetalType',
    'Color': 'Tone',
    'PD#': 'ItemRefNo',
    'Description': 'CustomerProductionInstruction',
    'Shefi#': 'SKUNo',
    'SHEFIPO#': 'SHEFIPO#',
    'CODE': 'DIA GRADE'
}, inplace=True)

# Add SrNo. as the first column
df_cleaned.insert(loc=0, column='SrNo.', value=range(1, len(df_cleaned) + 1))

# Add ItemSize after StyleCode
df_cleaned.insert(loc=2, column='ItemSize', value='')

# Insert 'OrderItemPcs' after 'OrderQty'
order_qty_index = df_cleaned.columns.get_loc('OrderQty')
df_cleaned.insert(loc=order_qty_index + 1, column='OrderItemPcs', value='')

# Add StockType and MakeType after ItemRefNo
item_ref_index = df_cleaned.columns.get_loc('ItemRefNo')
df_cleaned.insert(loc=item_ref_index + 1, column='StockType', value='')
df_cleaned.insert(loc=item_ref_index + 2, column='MakeType', value='')

# Insert 'OrderGroup' and 'Certificate' left of 'SKUNo'
sku_index = df_cleaned.columns.get_loc('SKUNo')
df_cleaned.insert(loc=sku_index, column='OrderGroup', value='SHEFI')
df_cleaned.insert(loc=sku_index + 1, column='Certificate', value='')

# Add 9 columns after SKUNo (now two columns to the right due to above insertions)
sku_index = df_cleaned.columns.get_loc('SKUNo')
new_columns = [
    'Basestoneminwt', 'Basestonemaxwt', 'Basemetalminwt', 'Basemetalmaxwt',
    'Productiondeliverydate', 'Expecteddeliverydate', 'null', 'SetPrice', 'StoneQuality'
]
for i, col in enumerate(new_columns):
    df_cleaned.insert(loc=sku_index + 1 + i, column=col, value='')

# Add ItemPoNo after Tone
tone_index = df_cleaned.columns.get_loc('Tone')

# Make sure po_value is defined, example:
po_value = '1916745'
df_cleaned.insert(loc=tone_index + 1, column='ItemPoNo', value=po_value)

# Create 'Metal' column from last char of StyleCode + numeric part of MetalType + Tone
df_cleaned['Metal'] = df_cleaned.apply(
    lambda row: str(row['StyleCode'])[-1] + re.sub(r'\D', '', str(row['MetalType'])) + str(row['Tone']),
    axis=1
)

# Replace 'MetalType' with 'Metal'
metal_type_index = df_cleaned.columns.get_loc('MetalType')
df_cleaned.drop(columns=['MetalType'], inplace=True)
metal_col = df_cleaned.pop('Metal')
df_cleaned.insert(loc=metal_type_index, column='Metal', value=metal_col)

# Create 'SpecialRemarks' column based on specified logic
df_cleaned['SpecialRemarks'] = df_cleaned.apply(
    lambda row: f"PD#, {row['ItemRefNo']}, SHEFI # {row['SKUNo']}, SHEFI PO# ,{row['SHEFIPO#']} ,{row['Metal']}, DIA QLTY {row['DIA GRADE']}",
    axis=1
)

# Insert SpecialRemarks column after CustomerProductionInstruction
cpi_index = df_cleaned.columns.get_loc('CustomerProductionInstruction')
special_remarks_col = df_cleaned.pop('SpecialRemarks')
df_cleaned.insert(loc=cpi_index + 1, column='SpecialRemarks', value=special_remarks_col)

# Display first 112 rows
df_cleaned.head(112)
#df_cleaned.to_excel(r"C:\Users\Admin\Desktop\output.xlsx", index=False)
# Out:
#     SrNo.    StyleCode ItemSize  OrderQty OrderItemPcs Metal Tone ItemPoNo  \
# 0       1   WP2350G-YG                6.0               G10Y    Y  1916745
# 6       2   WP2350G-WG                2.0               G10W    W  1916745
# 12      3   WP2350K-WG                1.0               G10W    W  1916745
# 18      4   WP2350A-YG                6.0               G10Y    Y  1916745
# 24      5   WP2350A-YG                6.0               G10Y    Y  1916745
# 30      6   WP2350A-WG                5.0               G10W    W  1916745
# 36      7   WP2350A-WG                5.0               G10W    W  1916745
# 42      8   WP2350C-WG                4.0               G10W    W  1916745
# 48      9   WP2350D-YG                4.0               G10Y    Y  1916745
# 54     10   WP2350D-WG                5.0               G10W    W  1916745
# 60     11   WP2350D-WG                5.0               G10W    W  1916745
# 65     12   WP2350E-YG                9.0               G10Y    Y  1916745
# 71     13   WP2350E-WG                9.0               G10W    W  1916745
# 77     14   WP2350F-YG                5.0               G10Y    Y  1916745
# 83     15   WP2350F-WG                9.0               G10W    W  1916745
# 89     16   WP2350X-WG                2.0               G10W    W  1916745
# 96     17   WP2350G-YG                2.0               G10Y    Y  1916745
#
#    ItemRefNo StockType  ... Basestonemaxwt Basemetalminwt Basemetalmaxwt  \
# 0    100969P            ...
# 6    100969P            ...
# 12   200646P            ...
# 18   110486P            ...
# 24   110486P            ...
# 30   110486P            ...
# 36   110486P            ...
# 42   101289P            ...
# 48   100967P            ...
# 54   100967P            ...
# 60   100967P            ...
# 65   110489P            ...
# 71   110489P            ...
# 77   100968P            ...
# 83   100968P            ...
# 89   201272E            ...
# 96   101289P            ...
#
#    Productiondeliverydate Expecteddeliverydate null SetPrice StoneQuality  \
# 0
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54
# 60
# 65
# 71
# 77
# 83
# 89
# 96
#
#      SHEFIPO# DIA GRADE
# 0   1916745.0   RDI2-DP
# 6   1916745.0   RDI2-DP
# 12  1916745.0   RDI2-DP
# 18  1916745.0   RDI2-DP
# 24  1916745.0   RDI2-DP
# 30  1916745.0   RDI2-DP
# 36  1916745.0   RDI2-DP
# 42  1916745.0   RDI2-DP
# 48  1916745.0   RDI2-DP
# 54  1916745.0   RDI2-DP
# 60  1916745.0   RDI2-DP
# 65  1916745.0   RDI2-DP
# 71  1916745.0   RDI2-DP
# 77  1916745.0   RDI2-DP
# 83  1916745.0   RDI2-DP
# 89  1916745.0   RDI2-DP
# 96  1916745.0   RDI2-DP
#
# [17 rows x 27 columns]

# %%
selected_columns = ['VendorStyle#', 'QTY', 'MetalType', 'Color', 'PD#', 'Description', 'Shefi#', 'SHEFIPO#', 'CODE']
df_selected = df[selected_columns]

# Drop rows with NaN values and make a copy
df_cleaned = df_selected.dropna().copy()

# Clean newline characters from 'Description'
df_cleaned['Description'] = df_cleaned['Description'].str.replace('\n', ' ', regex=True)

# Rename columns
df_cleaned.rename(columns={
    'VendorStyle#': 'StyleCode',
    'QTY': 'OrderQty',
    'MetalType': 'MetalType',
    'Color': 'Tone',
    'PD#': 'ItemRefNo',
    'Description': 'DesignProductionInstruction',
    'Shefi#': 'SKUNo',
    'SHEFIPO#': 'SHEFIPO#',
    'CODE': 'DIA GRADE'
}, inplace=True)

# Add SrNo. as the first column
df_cleaned.insert(loc=0, column='SrNo.', value=range(1, len(df_cleaned) + 1))

# Add ItemSize after StyleCode
df_cleaned.insert(loc=2, column='ItemSize', value='')

# Insert 'OrderItemPcs' after 'OrderQty'
order_qty_index = df_cleaned.columns.get_loc('OrderQty')
df_cleaned.insert(loc=order_qty_index + 1, column='OrderItemPcs', value='')

# Add StockType and MakeType after ItemRefNo
item_ref_index = df_cleaned.columns.get_loc('ItemRefNo')
df_cleaned.insert(loc=item_ref_index + 1, column='StockType', value='')
df_cleaned.insert(loc=item_ref_index + 2, column='MakeType', value='')

# Insert 'OrderGroup' and 'Certificate' left of 'SKUNo'
sku_index = df_cleaned.columns.get_loc('SKUNo')
df_cleaned.insert(loc=sku_index, column='OrderGroup', value='SHEFI')
df_cleaned.insert(loc=sku_index + 1, column='Certificate', value='')

# Add 9 columns after SKUNo
sku_index = df_cleaned.columns.get_loc('SKUNo')
new_columns = [
    'Basestoneminwt', 'Basestonemaxwt', 'Basemetalminwt', 'Basemetalmaxwt',
    'Productiondeliverydate', 'Expecteddeliverydate', 'null', 'SetPrice', 'StoneQuality'
]
for i, col in enumerate(new_columns):
    df_cleaned.insert(loc=sku_index + 1 + i, column=col, value='')

# Add ItemPoNo after Tone
tone_index = df_cleaned.columns.get_loc('Tone')
po_value = '1916745'  # Example PO value
df_cleaned.insert(loc=tone_index + 1, column='ItemPoNo', value=po_value)

# Create 'Metal' column using: last char of StyleCode + numeric part of MetalType + Tone
df_cleaned['Metal'] = df_cleaned.apply(
    lambda row: str(row['StyleCode'])[-1] + re.sub(r'\D', '', str(row['MetalType'])) + str(row['Tone']),
    axis=1
)

# Replace 'MetalType' column with 'Metal'
metal_type_index = df_cleaned.columns.get_loc('MetalType')
df_cleaned.drop(columns=['MetalType'], inplace=True)
metal_col = df_cleaned.pop('Metal')
df_cleaned.insert(loc=metal_type_index, column='Metal', value=metal_col)

# Add 'SpecialRemarks' column based on your defined logic
df_cleaned['SpecialRemarks'] = df_cleaned.apply(
    lambda row: f"PD#, {row['ItemRefNo']}, SHEFI # {row['SKUNo']}, SHEFI PO# ,{row['SHEFIPO#']} ,{row['Metal']}, DIA QLTY {row['DIA GRADE']}",
    axis=1
)

# Insert 'SpecialRemarks' after DesignProductionInstruction
dpi_index = df_cleaned.columns.get_loc('DesignProductionInstruction')
special_remarks_col = df_cleaned.pop('SpecialRemarks')
df_cleaned.insert(loc=dpi_index + 1, column='SpecialRemarks', value=special_remarks_col)

# Define mapping for StampInstruction from Metal
def get_stamp_instruction(metal):
    if metal in ["G14W", "G14Y", "G14P", "G14R"]:
        return "14K & DP2 LOGO"
    elif metal in ["G10W", "G10Y", "G10P", "G10R"]:
        return "10K & DP2 LOGO"
    elif metal in ["G18W", "G18Y", "G18P", "G18R"]:
        return "18K & DP2 LOGO"
    elif metal == "PC95":
        return "PT950 & DP2 LOGO"
    elif metal == "A4YUP342-":
        return "ALLOY & DP2 LOGO"
    elif metal == "AG925":
        return "KT & DP2 LOGO"
    else:
        return "0 & DP2 LOGO"

# Create and insert 'StampInstruction' after DesignProductionInstruction
df_cleaned['StampInstruction'] = df_cleaned['Metal'].apply(get_stamp_instruction)
df_cleaned.insert(loc=dpi_index + 2, column='StampInstruction', value=df_cleaned.pop('StampInstruction'))

# Save to Excel
df_cleaned.to_excel("final_output_with_stampinstruction.xlsx", index=False)

# Show preview
df_cleaned.head(112)
# Out:
#     SrNo.    StyleCode ItemSize  OrderQty OrderItemPcs Metal Tone ItemPoNo  \
# 0       1   WP2350G-YG                6.0               G10Y    Y  1916745
# 6       2   WP2350G-WG                2.0               G10W    W  1916745
# 12      3   WP2350K-WG                1.0               G10W    W  1916745
# 18      4   WP2350A-YG                6.0               G10Y    Y  1916745
# 24      5   WP2350A-YG                6.0               G10Y    Y  1916745
# 30      6   WP2350A-WG                5.0               G10W    W  1916745
# 36      7   WP2350A-WG                5.0               G10W    W  1916745
# 42      8   WP2350C-WG                4.0               G10W    W  1916745
# 48      9   WP2350D-YG                4.0               G10Y    Y  1916745
# 54     10   WP2350D-WG                5.0               G10W    W  1916745
# 60     11   WP2350D-WG                5.0               G10W    W  1916745
# 65     12   WP2350E-YG                9.0               G10Y    Y  1916745
# 71     13   WP2350E-WG                9.0               G10W    W  1916745
# 77     14   WP2350F-YG                5.0               G10Y    Y  1916745
# 83     15   WP2350F-WG                9.0               G10W    W  1916745
# 89     16   WP2350X-WG                2.0               G10W    W  1916745
# 96     17   WP2350G-YG                2.0               G10Y    Y  1916745
#
#    ItemRefNo StockType  ... Basestonemaxwt Basemetalminwt Basemetalmaxwt  \
# 0    100969P            ...
# 6    100969P            ...
# 12   200646P            ...
# 18   110486P            ...
# 24   110486P            ...
# 30   110486P            ...
# 36   110486P            ...
# 42   101289P            ...
# 48   100967P            ...
# 54   100967P            ...
# 60   100967P            ...
# 65   110489P            ...
# 71   110489P            ...
# 77   100968P            ...
# 83   100968P            ...
# 89   201272E            ...
# 96   101289P            ...
#
#    Productiondeliverydate Expecteddeliverydate null SetPrice StoneQuality  \
# 0
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54
# 60
# 65
# 71
# 77
# 83
# 89
# 96
#
#      SHEFIPO# DIA GRADE
# 0   1916745.0   RDI2-DP
# 6   1916745.0   RDI2-DP
# 12  1916745.0   RDI2-DP
# 18  1916745.0   RDI2-DP
# 24  1916745.0   RDI2-DP
# 30  1916745.0   RDI2-DP
# 36  1916745.0   RDI2-DP
# 42  1916745.0   RDI2-DP
# 48  1916745.0   RDI2-DP
# 54  1916745.0   RDI2-DP
# 60  1916745.0   RDI2-DP
# 65  1916745.0   RDI2-DP
# 71  1916745.0   RDI2-DP
# 77  1916745.0   RDI2-DP
# 83  1916745.0   RDI2-DP
# 89  1916745.0   RDI2-DP
# 96  1916745.0   RDI2-DP
#
# [17 rows x 28 columns]

# %%
selected_columns = ['VendorStyle#', 'QTY', 'MetalType', 'Color', 'PD#', 'Description', 'Shefi#', 'SHEFIPO#', 'CODE']
df_selected = df[selected_columns]

# Drop rows with NaN values and make a copy
df_cleaned = df_selected.dropna().copy()

# Clean newline characters from 'Description'
df_cleaned['Description'] = df_cleaned['Description'].str.replace('\n', ' ', regex=True)

# Rename columns
df_cleaned.rename(columns={
    'VendorStyle#': 'StyleCode',
    'QTY': 'OrderQty',
    'MetalType': 'MetalType',
    'Color': 'Tone',
    'PD#': 'ItemRefNo',
    'Description': 'DesignProductionInstruction',
    'Shefi#': 'SKUNo',
    'SHEFIPO#': 'SHEFIPO#',
    'CODE': 'DIA GRADE'
}, inplace=True)

# Add SrNo. as the first column
df_cleaned.insert(loc=0, column='SrNo.', value=range(1, len(df_cleaned) + 1))

# Add ItemSize after StyleCode
df_cleaned.insert(loc=2, column='ItemSize', value='')

# Insert 'OrderItemPcs' after 'OrderQty'
order_qty_index = df_cleaned.columns.get_loc('OrderQty')
df_cleaned.insert(loc=order_qty_index + 1, column='OrderItemPcs', value='')

# Fill OrderItemPcs based on 'DesignProductionInstruction'
df_cleaned['OrderItemPcs'] = df_cleaned['DesignProductionInstruction'].apply(
    lambda x: 1 if any(kw in str(x).upper() for kw in ['PEND', 'PENDENT']) else ''
)

# Add StockType and MakeType after ItemRefNo
item_ref_index = df_cleaned.columns.get_loc('ItemRefNo')
df_cleaned.insert(loc=item_ref_index + 1, column='StockType', value='')
df_cleaned.insert(loc=item_ref_index + 2, column='MakeType', value='')

# Insert 'OrderGroup' and 'Certificate' left of 'SKUNo'
sku_index = df_cleaned.columns.get_loc('SKUNo')
df_cleaned.insert(loc=sku_index, column='OrderGroup', value='SHEFI')
df_cleaned.insert(loc=sku_index + 1, column='Certificate', value='')

# Add 9 columns after SKUNo
sku_index = df_cleaned.columns.get_loc('SKUNo')
new_columns = [
    'Basestoneminwt', 'Basestonemaxwt', 'Basemetalminwt', 'Basemetalmaxwt',
    'Productiondeliverydate', 'Expecteddeliverydate', 'null', 'SetPrice', 'StoneQuality'
]
for i, col in enumerate(new_columns):
    df_cleaned.insert(loc=sku_index + 1 + i, column=col, value='')

# Add ItemPoNo after Tone
tone_index = df_cleaned.columns.get_loc('Tone')
po_value = '1916745'  # Example PO value
df_cleaned.insert(loc=tone_index + 1, column='ItemPoNo', value=po_value)

# Create 'Metal' column using: last char of StyleCode + numeric part of MetalType + Tone
df_cleaned['Metal'] = df_cleaned.apply(
    lambda row: str(row['StyleCode'])[-1] + re.sub(r'\D', '', str(row['MetalType'])) + str(row['Tone']),
    axis=1
)

# Replace 'MetalType' column with 'Metal'
metal_type_index = df_cleaned.columns.get_loc('MetalType')
df_cleaned.drop(columns=['MetalType'], inplace=True)
metal_col = df_cleaned.pop('Metal')
df_cleaned.insert(loc=metal_type_index, column='Metal', value=metal_col)

# Add 'SpecialRemarks' column based on your defined logic
df_cleaned['SpecialRemarks'] = df_cleaned.apply(
    lambda row: f"PD#, {row['ItemRefNo']}, SHEFI # {row['SKUNo']}, SHEFI PO# ,{row['SHEFIPO#']} ,{row['Metal']}, DIA QLTY {row['DIA GRADE']}",
    axis=1
)

# Insert 'SpecialRemarks' after DesignProductionInstruction
dpi_index = df_cleaned.columns.get_loc('DesignProductionInstruction')
special_remarks_col = df_cleaned.pop('SpecialRemarks')
df_cleaned.insert(loc=dpi_index + 1, column='SpecialRemarks', value=special_remarks_col)

# Define mapping for StampInstruction from Metal
def get_stamp_instruction(metal):
    if metal in ["G14W", "G14Y", "G14P", "G14R"]:
        return "14K & DP2 LOGO"
    elif metal in ["G10W", "G10Y", "G10P", "G10R"]:
        return "10K & DP2 LOGO"
    elif metal in ["G18W", "G18Y", "G18P", "G18R"]:
        return "18K & DP2 LOGO"
    elif metal == "PC95":
        return "PT950 & DP2 LOGO" #
    elif metal == "A4YUP342-":
        return "ALLOY & DP2 LOGO"#
    elif metal == "AG925":
        return "KT & DP2 LOGO"
    else:
        return "0 & DP2 LOGO"

# Create and insert 'StampInstruction' after DesignProductionInstruction
df_cleaned['StampInstruction'] = df_cleaned['Metal'].apply(get_stamp_instruction)
df_cleaned.insert(loc=dpi_index + 2, column='StampInstruction', value=df_cleaned.pop('StampInstruction'))

# Save to Excel
df_cleaned.to_excel("final_output_with_orderitempcs.xlsx", index=False)

# Show preview
print(df_cleaned[['DesignProductionInstruction', 'OrderItemPcs']].head(10))

# %%
# Step 1: Read cell A2 from Excel using openpyxl engine
po_value = pd.read_excel(r'C:\Users\Admin\Desktop\customer_seffi.xlsx', header=None, engine='openpyxl').iloc[1, 0] 
# Step 2: Read the actual data starting from row 11 (skip first 10 rows)
df = pd.read_excel(r'C:\Users\Admin\Desktop\customer_seffi.xlsx', skiprows=10)
# Select specific columns
selected_columns = ['VendorStyle#', 'QTY', 'MetalType', 'Color', 'PD#', 'Description', 'Shefi#', 'SHEFIPO#', 'CODE']
df_selected = df[selected_columns]

# Drop rows with NaN values and make a copy
df_cleaned = df_selected.dropna().copy()

# Removing \n from 'Description'
df_cleaned['Description'] = df_cleaned['Description'].str.replace('\n', ' ', regex=True)

# Rename columns(Mapping)
df_cleaned.rename(columns={
    'VendorStyle#': 'StyleCode',
    'QTY': 'OrderQty',
    'MetalType': 'MetalType',
    'Color': 'Tone',
    'PD#': 'ItemRefNo',
    'Description': 'CustomerProductionInstruction',
    'Shefi#': 'SKUNo',
    'SHEFIPO#': 'SHEFIPO#',
    'CODE': 'DIA GRADE'
}, inplace=True)

# Add SrNo. as the first column
df_cleaned.insert(loc=0, column='SrNo.', value=range(1, len(df_cleaned) + 1))

# Add ItemSize after StyleCode
df_cleaned.insert(loc=2, column='ItemSize', value='')

# Insert 'OrderItemPcs' after 'OrderQty' and set all values to 1
order_qty_index = df_cleaned.columns.get_loc('OrderQty')
df_cleaned.insert(loc=order_qty_index + 1, column='OrderItemPcs', value=1)

# Add StockType and MakeType after ItemRefNo
item_ref_index = df_cleaned.columns.get_loc('ItemRefNo')
df_cleaned.insert(loc=item_ref_index + 1, column='StockType', value='')
df_cleaned.insert(loc=item_ref_index + 2, column='MakeType', value='')

# Insert 'OrderGroup' and 'Certificate' before 'SKUNo'
sku_index = df_cleaned.columns.get_loc('SKUNo')
df_cleaned.insert(loc=sku_index, column='OrderGroup', value='SHEFI')
df_cleaned.insert(loc=sku_index + 1, column='Certificate', value='')

# Add 9 columns after SKUNo
sku_index = df_cleaned.columns.get_loc('SKUNo')
new_columns = [
    'Basestoneminwt', 'Basestonemaxwt', 'Basemetalminwt', 'Basemetalmaxwt',
    'Productiondeliverydate', 'Expecteddeliverydate', 'null', 'SetPrice', 'StoneQuality'
]
for i, col in enumerate(new_columns):
    df_cleaned.insert(loc=sku_index + 1 + i, column=col, value='')

# Insert 'ItemPoNo' after 'Tone'
tone_index = df_cleaned.columns.get_loc('Tone')
df_cleaned.insert(loc=tone_index + 1, column='ItemPoNo', value=po_value)

# Create 'Metal' column using: last char of StyleCode + numeric part of MetalType + Tone
df_cleaned['Metal'] = df_cleaned.apply(
    lambda row: str(row['StyleCode'])[-1] + re.sub(r'\D', '', str(row['MetalType'])) + str(row['Tone']),
    axis=1
)

# Replace 'MetalType' column with 'Metal'
metal_type_index = df_cleaned.columns.get_loc('MetalType')
df_cleaned.drop(columns=['MetalType'], inplace=True)
metal_col = df_cleaned.pop('Metal')
df_cleaned.insert(loc=metal_type_index, column='Metal', value=metal_col)

# Add 'SpecialRemarks' column based on logic
df_cleaned['SpecialRemarks'] = df_cleaned.apply(
    lambda row: f"PD#, {row['ItemRefNo']}, SHEFI # {row['SKUNo']}, SHEFI PO# ,{row['SHEFIPO#']} ,{row['Metal']}, DIA QLTY {row['DIA GRADE']}",
    axis=1
)

# Insert 'SpecialRemarks' after DesignProductionInstruction
dpi_index = df_cleaned.columns.get_loc('CustomerProductionInstruction')
special_remarks_col = df_cleaned.pop('SpecialRemarks')
df_cleaned.insert(loc=dpi_index + 1, column='SpecialRemarks', value=special_remarks_col)

# Define logic for 'StampInstruction'
def get_stamp_instruction(metal):
    if metal in ["G14W", "G14Y", "G14P", "G14R"]:
        return "14K & DP2 LOGO"
    elif metal in ["G10W", "G10Y", "G10P", "G10R"]:
        return "10K & DP2 LOGO"
    elif metal in ["G18W", "G18Y", "G18P", "G18R"]:
        return "18K & DP2 LOGO"
    elif metal == "PC95":
        return "PT950 & DP2 LOGO"
    elif metal == "A4YUP342-":
        return "ALLOY & DP2 LOGO"
    elif metal == "AG925":
        return "KT & DP2 LOGO"
    else:
        return "0 & DP2 LOGO"

# Insert 'StampInstruction' right of DesignProductionInstruction
df_cleaned['StampInstruction'] = df_cleaned['Metal'].apply(get_stamp_instruction)
df_cleaned.insert(loc=dpi_index + 2, column='StampInstruction', value=df_cleaned.pop('StampInstruction'))

# Save to Excel
df_cleaned.to_excel("final_output_orderitempcs_2.xlsx", in dex=False)

# Preview first few rows
df_cleaned.head(112)
# Out:
#     SrNo.    StyleCode ItemSize  OrderQty  OrderItemPcs Metal Tone  \
# 0       1   WP2350G-YG                6.0             1  G10Y    Y
# 6       2   WP2350G-WG                2.0             1  G10W    W
# 12      3   WP2350K-WG                1.0             1  G10W    W
# 18      4   WP2350A-YG                6.0             1  G10Y    Y
# 24      5   WP2350A-YG                6.0             1  G10Y    Y
# 30      6   WP2350A-WG                5.0             1  G10W    W
# 36      7   WP2350A-WG                5.0             1  G10W    W
# 42      8   WP2350C-WG                4.0             1  G10W    W
# 48      9   WP2350D-YG                4.0             1  G10Y    Y
# 54     10   WP2350D-WG                5.0             1  G10W    W
# 60     11   WP2350D-WG                5.0             1  G10W    W
# 65     12   WP2350E-YG                9.0             1  G10Y    Y
# 71     13   WP2350E-WG                9.0             1  G10W    W
# 77     14   WP2350F-YG                5.0             1  G10Y    Y
# 83     15   WP2350F-WG                9.0             1  G10W    W
# 89     16   WP2350X-WG                2.0             1  G10W    W
# 96     17   WP2350G-YG                2.0             1  G10Y    Y
#
#          ItemPoNo ItemRefNo StockType  ... Basestonemaxwt Basemetalminwt  \
# 0   PO# SJS2_0028   100969P            ...
# 6   PO# SJS2_0028   100969P            ...
# 12  PO# SJS2_0028   200646P            ...
# 18  PO# SJS2_0028   110486P            ...
# 24  PO# SJS2_0028   110486P            ...
# 30  PO# SJS2_0028   110486P            ...
# 36  PO# SJS2_0028   110486P            ...
# 42  PO# SJS2_0028   101289P            ...
# 48  PO# SJS2_0028   100967P            ...
# 54  PO# SJS2_0028   100967P            ...
# 60  PO# SJS2_0028   100967P            ...
# 65  PO# SJS2_0028   110489P            ...
# 71  PO# SJS2_0028   110489P            ...
# 77  PO# SJS2_0028   100968P            ...
# 83  PO# SJS2_0028   100968P            ...
# 89  PO# SJS2_0028   201272E            ...
# 96  PO# SJS2_0028   101289P            ...
#
#    Basemetalmaxwt Productiondeliverydate Expecteddeliverydate null SetPrice  \
# 0
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54
# 60
# 65
# 71
# 77
# 83
# 89
# 96
#
#    StoneQuality   SHEFIPO# DIA GRADE
# 0                1916745.0   RDI2-DP
# 6                1916745.0   RDI2-DP
# 12               1916745.0   RDI2-DP
# 18               1916745.0   RDI2-DP
# 24               1916745.0   RDI2-DP
# 30               1916745.0   RDI2-DP
# 36               1916745.0   RDI2-DP
# 42               1916745.0   RDI2-DP
# 48               1916745.0   RDI2-DP
# 54               1916745.0   RDI2-DP
# 60               1916745.0   RDI2-DP
# 65               1916745.0   RDI2-DP
# 71               1916745.0   RDI2-DP
# 77               1916745.0   RDI2-DP
# 83               1916745.0   RDI2-DP
# 89               1916745.0   RDI2-DP
# 96               1916745.0   RDI2-DP
#
# [17 rows x 28 columns]

# %%
#Final Code For SHEFI WITH NULL COLN
#import pandas as pd
#import re

# Step 1: Read cell A2 from Excel using openpyxl engine
po_value = pd.read_excel(r'C:\Users\Admin\Desktop\customer_seffi.xlsx', header=None, engine='openpyxl').iloc[1, 0]

# Step 2: Read the actual data starting from row 11 (skip first 10 rows)
df = pd.read_excel(r'C:\Users\Admin\Desktop\customer_seffi.xlsx', skiprows=10)

# Select specific columns
selected_columns = ['VendorStyle#', 'QTY', 'MetalType', 'Color', 'PD#', 'Description', 'Shefi#', 'SHEFIPO#', 'CODE']
df_selected = df[selected_columns]

# Drop rows with NaN values and make a copy
df_cleaned = df_selected.dropna().copy()

# Clean newline characters from 'Description'
df_cleaned['Description'] = df_cleaned['Description'].str.replace('\n', ' ', regex=True)

# Rename columns
df_cleaned.rename(columns={
    'VendorStyle#': 'StyleCode',
    'QTY': 'OrderQty',
    'MetalType': 'MetalType',
    'Color': 'Tone',
    'PD#': 'ItemRefNo',
    'Description': 'CustomerProductionInstruction',
    'Shefi#': 'SKUNo',
    'SHEFIPO#': 'SHEFIPO#',
    'CODE': 'DIA GRADE'
}, inplace=True)

# Add SrNo. as the first column
df_cleaned.insert(loc=0, column='SrNo.', value=range(1, len(df_cleaned) + 1))

# Add ItemSize after StyleCode
df_cleaned.insert(loc=2, column='ItemSize', value='')

# Insert 'OrderItemPcs' after 'OrderQty' and set all values to 1
order_qty_index = df_cleaned.columns.get_loc('OrderQty')
df_cleaned.insert(loc=order_qty_index + 1, column='OrderItemPcs', value=1)

# Add StockType and MakeType after ItemRefNo
item_ref_index = df_cleaned.columns.get_loc('ItemRefNo')
df_cleaned.insert(loc=item_ref_index + 1, column='StockType', value='')
df_cleaned.insert(loc=item_ref_index + 2, column='MakeType', value='')

# Insert 'OrderGroup' and 'Certificate' before 'SKUNo'
sku_index = df_cleaned.columns.get_loc('SKUNo')
df_cleaned.insert(loc=sku_index, column='OrderGroup', value='SHEFI')
df_cleaned.insert(loc=sku_index + 1, column='Certificate', value='')

# Add 9 columns after SKUNo
sku_index = df_cleaned.columns.get_loc('SKUNo')
new_columns = [
    'Basestoneminwt', 'Basestonemaxwt', 'Basemetalminwt', 'Basemetalmaxwt',
    'Productiondeliverydate', 'Expecteddeliverydate', 'null', 'SetPrice', 'StoneQuality'
]
for i, col in enumerate(new_columns):
    df_cleaned.insert(loc=sku_index + 1 + i, column=col, value='')

# Insert 'ItemPoNo' after 'Tone'
tone_index = df_cleaned.columns.get_loc('Tone')
df_cleaned.insert(loc=tone_index + 1, column='ItemPoNo', value=po_value)

# Create 'Metal' column using: last char of StyleCode + numeric part of MetalType + Tone
df_cleaned['Metal'] = df_cleaned.apply(
    lambda row: str(row['StyleCode'])[-1] + re.sub(r'\D', '', str(row['MetalType'])) + str(row['Tone']),
    axis=1
)

# Replace 'MetalType' column with 'Metal'
metal_type_index = df_cleaned.columns.get_loc('MetalType')
df_cleaned.drop(columns=['MetalType'], inplace=True)
metal_col = df_cleaned.pop('Metal')
df_cleaned.insert(loc=metal_type_index, column='Metal', value=metal_col)

# Add 'SpecialRemarks' column
df_cleaned['SpecialRemarks'] = df_cleaned.apply(
    lambda row: f"PD#, {row['ItemRefNo']}, SHEFI # {row['SKUNo']}, SHEFI PO# ,{row['SHEFIPO#']} ,{row['Metal']}, DIA QLTY {row['DIA GRADE']}",
    axis=1
)

# Insert 'SpecialRemarks' after CustomerProductionInstruction
dpi_index = df_cleaned.columns.get_loc('CustomerProductionInstruction')
special_remarks_col = df_cleaned.pop('SpecialRemarks')
df_cleaned.insert(loc=dpi_index + 1, column='SpecialRemarks', value=special_remarks_col)

# ✅ Insert 'DesignProductionInstruction' after 'SpecialRemarks'
df_cleaned.insert(loc=dpi_index + 2, column='DesignProductionInstruction', value='')

# Define logic for 'StampInstruction'
def get_stamp_instruction(metal):
    if metal in ["G14W", "G14Y", "G14P", "G14R"]:
        return "14K & DP2 LOGO"
    elif metal in ["G10W", "G10Y", "G10P", "G10R"]:
        return "10K & DP2 LOGO"
    elif metal in ["G18W", "G18Y", "G18P", "G18R"]:
        return "18K & DP2 LOGO"
    elif metal == "PC95":
        return "PT950 & DP2 LOGO"
    elif metal == "A4YUP342-":
        return "ALLOY & DP2 LOGO"
    elif metal == "AG925":
        return "KT & DP2 LOGO"
    else:
        return "0 & DP2 LOGO"

# Insert 'StampInstruction' after 'DesignProductionInstruction'
df_cleaned['StampInstruction'] = df_cleaned['Metal'].apply(get_stamp_instruction)
df_cleaned.insert(loc=dpi_index + 3, column='StampInstruction', value=df_cleaned.pop('StampInstruction'))

# Save to Excel
df_cleaned.to_excel("GATI_FORMAT.xlsx", index=False)

# Preview
print(df_cleaned.head(112))
# Out:
#     SrNo.    StyleCode ItemSize  OrderQty  OrderItemPcs Metal Tone  \
# 0       1   WP2350G-YG                6.0             1  G10Y    Y
# 6       2   WP2350G-WG                2.0             1  G10W    W
# 12      3   WP2350K-WG                1.0             1  G10W    W
# 18      4   WP2350A-YG                6.0             1  G10Y    Y
# 24      5   WP2350A-YG                6.0             1  G10Y    Y
# 30      6   WP2350A-WG                5.0             1  G10W    W
# 36      7   WP2350A-WG                5.0             1  G10W    W
# 42      8   WP2350C-WG                4.0             1  G10W    W
# 48      9   WP2350D-YG                4.0             1  G10Y    Y
# 54     10   WP2350D-WG                5.0             1  G10W    W
# 60     11   WP2350D-WG                5.0             1  G10W    W
# 65     12   WP2350E-YG                9.0             1  G10Y    Y
# 71     13   WP2350E-WG                9.0             1  G10W    W
# 77     14   WP2350F-YG                5.0             1  G10Y    Y
# 83     15   WP2350F-WG                9.0             1  G10W    W
# 89     16   WP2350X-WG                2.0             1  G10W    W
# 96     17   WP2350G-YG                2.0             1  G10Y    Y
#
#          ItemPoNo ItemRefNo StockType  ... Basestonemaxwt Basemetalminwt  \
# 0   PO# SJS2_0028   100969P            ...
# 6   PO# SJS2_0028   100969P            ...
# 12  PO# SJS2_0028   200646P            ...
# 18  PO# SJS2_0028   110486P            ...
# 24  PO# SJS2_0028   110486P            ...
# 30  PO# SJS2_0028   110486P            ...
# 36  PO# SJS2_0028   110486P            ...
# 42  PO# SJS2_0028   101289P            ...
# 48  PO# SJS2_0028   100967P            ...
# 54  PO# SJS2_0028   100967P            ...
# 60  PO# SJS2_0028   100967P            ...
# 65  PO# SJS2_0028   110489P            ...
# 71  PO# SJS2_0028   110489P            ...
# 77  PO# SJS2_0028   100968P            ...
# 83  PO# SJS2_0028   100968P            ...
# 89  PO# SJS2_0028   201272E            ...
# 96  PO# SJS2_0028   101289P            ...
#
#    Basemetalmaxwt Productiondeliverydate Expecteddeliverydate null SetPrice  \
# 0
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54
# 60
# 65
# 71
# 77
# 83
# 89
# 96
#
#    StoneQuality   SHEFIPO# DIA GRADE
# 0                1916745.0   RDI2-DP
# 6                1916745.0   RDI2-DP
# 12               1916745.0   RDI2-DP
# 18               1916745.0   RDI2-DP
# 24               1916745.0   RDI2-DP
# 30               1916745.0   RDI2-DP
# 36               1916745.0   RDI2-DP
# 42               1916745.0   RDI2-DP
# 48               1916745.0   RDI2-DP
# 54               1916745.0   RDI2-DP
# 60               1916745.0   RDI2-DP
# 65               1916745.0   RDI2-DP
# 71               1916745.0   RDI2-DP
# 77               1916745.0   RDI2-DP
# 83               1916745.0   RDI2-DP
# 89               1916745.0   RDI2-DP
# 96               1916745.0   RDI2-DP
#
# [17 rows x 29 columns]

# %%
#Final Code For SHEFI WITHOUT NULL COLN
import pandas as pd
import re

# Step 1: Read cell A2 from Excel using openpyxl engine
po_value = pd.read_excel(r'C:\Users\Admin\Desktop\customer_seffi.xlsx', header=None, engine='openpyxl').iloc[1, 0]

# Step 2: Read the actual data starting from row  11 (skip first 10 rows)
df = pd.read_excel(r'C:\Users\Admin\Desktop\customer_seffi.xlsx', skiprows=10)

# Select specific columns
selected_columns = ['VendorStyle#', 'QTY', 'MetalType', 'Color', 'PD#', 'Description', 'Shefi#', 'SHEFIPO#', 'CODE']
df_selected = df[selected_columns]

# Drop rows with NaN values and make a copy
df_cleaned = df_selected.dropna().copy()

# Clean newline characters from 'Description'
df_cleaned['Description'] = df_cleaned['Description'].str.replace('\n', ' ', regex=True)

# Rename columns
df_cleaned.rename(columns={
    'VendorStyle#': 'StyleCode',
    'QTY': 'OrderQty',
    'MetalType': 'MetalType',
    'Color': 'Tone',
    'PD#': 'ItemRefNo',
    'Description': 'CustomerProductionInstruction',
    'Shefi#': 'SKUNo',
    'SHEFIPO#': 'SHEFIPO#',
    'CODE': 'DIA GRADE'
}, inplace=True)

# Add SrNo. as the first column
df_cleaned.insert(loc=0, column='SrNo.', value=range(1, len(df_cleaned) + 1))

# Add ItemSize after StyleCode
df_cleaned.insert(loc=2, column='ItemSize', value='')

# Insert 'OrderItemPcs' after 'OrderQty' and set all values to 1
order_qty_index = df_cleaned.columns.get_loc('OrderQty')
df_cleaned.insert(loc=order_qty_index + 1, column='OrderItemPcs', value=1)

# Add StockType and MakeType after ItemRefNo
item_ref_index = df_cleaned.columns.get_loc('ItemRefNo')
df_cleaned.insert(loc=item_ref_index + 1, column='StockType', value='')
df_cleaned.insert(loc=item_ref_index + 2, column='MakeType', value='')

# Insert 'OrderGroup' and 'Certificate' before 'SKUNo'
sku_index = df_cleaned.columns.get_loc('SKUNo')
df_cleaned.insert(loc=sku_index, column='OrderGroup', value='SHEFI')
df_cleaned.insert(loc=sku_index + 1, column='Certificate', value='')

# Add 9 columns after SKUNo
sku_index = df_cleaned.columns.get_loc('SKUNo')
new_columns = [
    'Basestoneminwt', 'Basestonemaxwt', 'Basemetalminwt', 'Basemetalmaxwt',
    'Productiondeliverydate', 'Expecteddeliverydate', 'SetPrice', 'StoneQuality'
]
for i, col in enumerate(new_columns):
    df_cleaned.insert(loc=sku_index + 1 + i, column=col, value='')

# Insert 'ItemPoNo' after 'Tone'
tone_index = df_cleaned.columns.get_loc('Tone')
df_cleaned.insert(loc=tone_index + 1, column='ItemPoNo', value=po_value)

# Create 'Metal' column using: last char of StyleCode + numeric part of MetalType + Tone
df_cleaned['Metal'] = df_cleaned.apply(
    lambda row: 'G' + re.sub(r'\D', '', str(row['MetalType'])) + str(row['Tone']),
    axis=1
)

# Replace 'MetalType' column with 'Metal'
metal_type_index = df_cleaned.columns.get_loc('MetalType')
df_cleaned.drop(columns=['MetalType'], inplace=True)
metal_col = df_cleaned.pop('Metal')
df_cleaned.insert(loc=metal_type_index, column='Metal', value=metal_col)

# Add 'SpecialRemarks' column
df_cleaned['SpecialRemarks'] = df_cleaned.apply(
    lambda row: f"PD#, {row['ItemRefNo']}, SHEFI # {row['SKUNo']}, SHEFI PO# ,{row['SHEFIPO#']} ,{row['Metal']}, DIA QLTY {row['DIA GRADE']}",
    axis=1
)

# Insert 'SpecialRemarks' after CustomerProductionInstruction
dpi_index = df_cleaned.columns.get_loc('CustomerProductionInstruction')
special_remarks_col = df_cleaned.pop('SpecialRemarks')
df_cleaned.insert(loc=dpi_index + 1, column='SpecialRemarks', value=special_remarks_col)

# ✅ Insert 'DesignProductionInstruction' after 'SpecialRemarks'
df_cleaned.insert(loc=dpi_index + 2, column='DesignProductionInstruction', value='')

# Define logic for 'StampInstruction'
def get_stamp_instruction(metal):
    if metal in ["G14W", "G14Y", "G14P", "G14R"]:
        return "14K & DP2 LOGO"
    elif metal in ["G10W", "G10Y", "G10P", "G10R"]:
        return "10K & DP2 LOGO"
    elif metal in ["G18W", "G18Y", "G18P", "G18R"]:
        return "18K & DP2 LOGO"
    elif metal == "PC95":
        return "PT950 & DP2 LOGO"
    elif metal == "A4YUP342-":
        return "ALLOY & DP2 LOGO"
    elif metal == "AG925":
        return "KT & DP2 LOGO"
    else:
        return "0 & DP2 LOGO"

# Insert 'StampInstruction' after 'DesignProductionInstruction'
df_cleaned['StampInstruction'] = df_cleaned['Metal'].apply(get_stamp_instruction)
df_cleaned.insert(loc=dpi_index + 3, column='StampInstruction', value=df_cleaned.pop('StampInstruction'))

# Save to Excel
#df_cleaned.to_excel("GATI_FORMAT_SHEFI.xlsx", index=False)

# Preview
print(df_cleaned.head(112))
# Out:
#     SrNo.    StyleCode ItemSize  OrderQty  OrderItemPcs Metal Tone  \
# 0       1   WP2350G-YG                6.0             1  G10Y    Y
# 6       2   WP2350G-WG                2.0             1  G10W    W
# 12      3   WP2350K-WG                1.0             1  G10W    W
# 18      4   WP2350A-YG                6.0             1  G10Y    Y
# 24      5   WP2350A-YG                6.0             1  G10Y    Y
# 30      6   WP2350A-WG                5.0             1  G10W    W
# 36      7   WP2350A-WG                5.0             1  G10W    W
# 42      8   WP2350C-WG                4.0             1  G10W    W
# 48      9   WP2350D-YG                4.0             1  G10Y    Y
# 54     10   WP2350D-WG                5.0             1  G10W    W
# 60     11   WP2350D-WG                5.0             1  G10W    W
# 65     12   WP2350E-YG                9.0             1  G10Y    Y
# 71     13   WP2350E-WG                9.0             1  G10W    W
# 77     14   WP2350F-YG                5.0             1  G10Y    Y
# 83     15   WP2350F-WG                9.0             1  G10W    W
# 89     16   WP2350X-WG                2.0             1  G10W    W
# 96     17   WP2350G-YG                2.0             1  G10Y    Y
#
#          ItemPoNo ItemRefNo StockType  ... Basestoneminwt Basestonemaxwt  \
# 0   PO# SJS2_0028   100969P            ...
# 6   PO# SJS2_0028   100969P            ...
# 12  PO# SJS2_0028   200646P            ...
# 18  PO# SJS2_0028   110486P            ...
# 24  PO# SJS2_0028   110486P            ...
# 30  PO# SJS2_0028   110486P            ...
# 36  PO# SJS2_0028   110486P            ...
# 42  PO# SJS2_0028   101289P            ...
# 48  PO# SJS2_0028   100967P            ...
# 54  PO# SJS2_0028   100967P            ...
# 60  PO# SJS2_0028   100967P            ...
# 65  PO# SJS2_0028   110489P            ...
# 71  PO# SJS2_0028   110489P            ...
# 77  PO# SJS2_0028   100968P            ...
# 83  PO# SJS2_0028   100968P            ...
# 89  PO# SJS2_0028   201272E            ...
# 96  PO# SJS2_0028   101289P            ...
#
#    Basemetalminwt Basemetalmaxwt Productiondeliverydate Expecteddeliverydate  \
# 0
# 6
# 12
# 18
# 24
# 30
# 36
# 42
# 48
# 54
# 60
# 65
# 71
# 77
# 83
# 89
# 96
#
#    SetPrice StoneQuality   SHEFIPO# DIA GRADE
# 0                         1916745.0   RDI2-DP
# 6                         1916745.0   RDI2-DP
# 12                        1916745.0   RDI2-DP
# 18                        1916745.0   RDI2-DP
# 24                        1916745.0   RDI2-DP
# 30                        1916745.0   RDI2-DP
# 36                        1916745.0   RDI2-DP
# 42                        1916745.0   RDI2-DP
# 48                        1916745.0   RDI2-DP
# 54                        1916745.0   RDI2-DP
# 60                        1916745.0   RDI2-DP
# 65                        1916745.0   RDI2-DP
# 71                        1916745.0   RDI2-DP
# 77                        1916745.0   RDI2-DP
# 83                        1916745.0   RDI2-DP
# 89                        1916745.0   RDI2-DP
# 96                        1916745.0   RDI2-DP
#
# [17 rows x 28 columns]

# %%
print(df_cleaned.dtypes['SrNo.'])
# Out:
# int64

# %%
#Final Code For SHEFI WITHOUT NULL COLN NA LOGIC ADDED
import pandas as pd
import re

# Step 1: Read cell A2 from Excel using openpyxl engine
po_value = pd.read_excel(r"C:\Users\Admin\Downloads\PO# SJS1_0250_DT-08.OCTOBER-QTY-30.xlsx", header=None, engine='openpyxl').iloc[1, 0]

# Step 2: Read the actual data starting from row  11 (skip first 10 rows)
df = pd.read_excel(r"C:\Users\Admin\Downloads\PO# SJS1_0250_DT-08.OCTOBER-QTY-30.xlsx", skiprows=10)

# Select specific columns
selected_columns = ['VendorStyle#', 'QTY', 'MetalType', 'Color', 'PD#', 'Description', 'Shefi#', 'SHEFIPO#', 'CODE']
df_selected = df[selected_columns]

# Drop rows with NaN values and make a copy
df_cleaned = df_selected.dropna().copy()


# Clean newline characters from 'Description'
df_cleaned['Description'] = df_cleaned['Description'].str.replace('\n', ' ', regex=True)

# Rename columns
df_cleaned.rename(columns={
    'VendorStyle#': 'StyleCode',
    'QTY': 'OrderQty',
    'MetalType': 'MetalType',
    'Color': 'Tone',
    'PD#': 'ItemRefNo',
    'Description': 'CustomerProductionInstruction',
    'Shefi#': 'SKUNo',
    'SHEFIPO#': 'SHEFIPO#',
    'CODE': 'DIA GRADE'
}, inplace=True)

# Add SrNo. as the first column
df_cleaned.insert(loc=0, column='SrNo.', value=range(1, len(df_cleaned) + 1))

# Add ItemSize after StyleCode
df_cleaned.insert(loc=2, column='ItemSize', value='')

# Insert 'OrderItemPcs' after 'OrderQty' and set all values to 1
order_qty_index = df_cleaned.columns.get_loc('OrderQty')
df_cleaned.insert(loc=order_qty_index + 1, column='OrderItemPcs', value=1)

# Add StockType and MakeType after ItemRefNo
item_ref_index = df_cleaned.columns.get_loc('ItemRefNo')
df_cleaned.insert(loc=item_ref_index + 1, column='StockType', value='')
df_cleaned.insert(loc=item_ref_index + 2, column='MakeType', value='')

# Insert 'OrderGroup' and 'Certificate' before 'SKUNo'
sku_index = df_cleaned.columns.get_loc('SKUNo')
df_cleaned.insert(loc=sku_index, column='OrderGroup', value='SHEFI')
df_cleaned.insert(loc=sku_index + 1, column='Certificate', value='')

# Add 9 columns after SKUNo
sku_index = df_cleaned.columns.get_loc('SKUNo')
new_columns = [
    'Basestoneminwt', 'Basestonemaxwt', 'Basemetalminwt', 'Basemetalmaxwt',
    'Productiondeliverydate', 'Expecteddeliverydate', 'SetPrice', 'StoneQuality'
]
for i, col in enumerate(new_columns):
    df_cleaned.insert(loc=sku_index + 1 + i, column=col, value='')

# Insert 'ItemPoNo' after 'Tone'
tone_index = df_cleaned.columns.get_loc('Tone')
df_cleaned.insert(loc=tone_index + 1, column='ItemPoNo', value=po_value)

# Create 'Metal' column using: last char of StyleCode + numeric part of MetalType + Tone
df_cleaned['Metal'] = df_cleaned.apply(
    lambda row: 'G' + re.sub(r'\D', '', str(row['MetalType'])) + str(row['Tone']),
    axis=1
)

# Replace 'MetalType' column with 'Metal'
metal_type_index = df_cleaned.columns.get_loc('MetalType')
df_cleaned.drop(columns=['MetalType'], inplace=True)
metal_col = df_cleaned.pop('Metal')
df_cleaned.insert(loc=metal_type_index, column='Metal', value=metal_col)

# Add 'SpecialRemarks' column
df_cleaned['SpecialRemarks'] = df_cleaned.apply(
    lambda row: f"PD#, {row['ItemRefNo']}, SHEFI # {row['SKUNo']}, SHEFI PO# ,{row['SHEFIPO#']} ,{row['Metal']}, DIA QLTY {row['DIA GRADE']}",
    axis=1
)

# Insert 'SpecialRemarks' after CustomerProductionInstruction
dpi_index = df_cleaned.columns.get_loc('CustomerProductionInstruction')
special_remarks_col = df_cleaned.pop('SpecialRemarks')
df_cleaned.insert(loc=dpi_index + 1, column='SpecialRemarks', value=special_remarks_col)

# ✅ Insert 'DesignProductionInstruction' after 'SpecialRemarks'
df_cleaned.insert(loc=dpi_index + 2, column='DesignProductionInstruction', value='')

# Define logic for 'StampInstruction'
def get_stamp_instruction(metal):
    if metal in ["G14W", "G14Y", "G14P", "G14R"]:
        return "14K & DP2 LOGO"
    elif metal in ["G10W", "G10Y", "G10P", "G10R"]:
        return "10K & DP2 LOGO"
    elif metal in ["G18W", "G18Y", "G18P", "G18R"]:
        return "18K & DP2 LOGO"
    elif metal == "PC95":
        return "PT950 & DP2 LOGO"
    elif metal == "A4YUP342-":
        return "ALLOY & DP2 LOGO"
    elif metal == "AG925":
        return "KT & DP2 LOGO"
    else:
        return "0 & DP2 LOGO"

# Replace StyleCode "N.A." with ItemRefNo
df_cleaned['StyleCode'] = df_cleaned.apply(
    lambda row: row['ItemRefNo'] if str(row['StyleCode']).strip().upper() == "N.A." else row['StyleCode'],
    axis=1
)

# Insert 'StampInstruction' after 'DesignProductionInstruction'
df_cleaned['StampInstruction'] = df_cleaned['Metal'].apply(get_stamp_instruction)
df_cleaned.insert(loc=dpi_index + 3, column='StampInstruction', value=df_cleaned.pop('StampInstruction'))

# Save to Excel
df_cleaned.to_excel("GATI_FORMAT_SHEFI_NA.xlsx", index=False)

# Preview
print(df_cleaned.head(112))
# Out:
#     SrNo.   StyleCode ItemSize  OrderQty  OrderItemPcs Metal Tone  \
# 0       1  XE0611A-YG                2.0             1  G10Y    Y
# 5       2  XE0611D-WG                2.0             1  G10W    W
# 10      3  XE0611F-WG                2.0             1  G10W    W
# 15      4     202424E                1.0             1  G10W    W
# 22      5     202427E                1.0             1  G10W    W
# 29      6     202424E                1.0             1  G10Y    Y
# 34      7     202427E                1.0             1  G10Y    Y
# 41      8     202427E                2.0             1  G10Y    Y
# 48      9     202427E                2.0             1  G10W    W
# 55     10     202426E                3.0             1  G10W    W
# 62     11     202425E                3.0             1  G10Y    Y
# 69     12     202425E                3.0             1  G10W    W
# 75     13     202424E                3.0             1  G10Y    Y
# 81     14     202424E                3.0             1  G10W    W
# 88     15  WR4147H-WG                1.0             1  G14W    W
#
#          ItemPoNo ItemRefNo StockType  ... Basestoneminwt Basestonemaxwt  \
# 0   PO# SJS1_0250   202393E            ...
# 5   PO# SJS1_0250   202395E            ...
# 10  PO# SJS1_0250   202397E            ...
# 15  PO# SJS1_0250   202424E            ...
# 22  PO# SJS1_0250   202427E            ...
# 29  PO# SJS1_0250   202424E            ...
# 34  PO# SJS1_0250   202427E            ...
# 41  PO# SJS1_0250   202427E            ...
# 48  PO# SJS1_0250   202427E            ...
# 55  PO# SJS1_0250   202426E            ...
# 62  PO# SJS1_0250   202425E            ...
# 69  PO# SJS1_0250   202425E            ...
# 75  PO# SJS1_0250   202424E            ...
# 81  PO# SJS1_0250   202424E            ...
# 88  PO# SJS1_0250   200024R            ...
#
#    Basemetalminwt Basemetalmaxwt Productiondeliverydate Expecteddeliverydate  \
# 0
# 5
# 10
# 15
# 22
# 29
# 34
# 41
# 48
# 55
# 62
# 69
# 75
# 81
# 88
#
#    SetPrice StoneQuality  SHEFIPO# DIA GRADE
# 0                         192958.0   RDI2-DP
# 5                         192958.0   RDI2-DP
# 10                        192958.0   RDI2-DP
# 15                        192959.0   RDI2-DP
# 22                        192959.0   RDI2-DP
# 29                        192959.0   RDI2-DP
# 34                        192959.0   RDI2-DP
# 41                        192960.0   RDI2-DP
# 48                        192960.0   RDI2-DP
# 55                        192960.0   RDI2-DP
# 62                        192960.0   RDI2-DP
# 69                        192960.0   RDI2-DP
# 75                        192960.0   RDI2-DP
# 81                        192960.0   RDI2-DP
# 88                        192965.0   RDI2-DP
#
# [15 rows x 28 columns]
